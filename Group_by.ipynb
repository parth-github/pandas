# %% [markdown]
# <a href="https://colab.research.google.com/github/parth-github/pandas/blob/master/Group_by.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas Group by

# %%
import numpy as np
import pandas as pd

# %%
# @title Create a DataFrame from dictionary

d = {
    'Company': ['GOOG', 'MSFT', 'AMZ', 'GOOG', 'MSFT', 'AMZ'],
    'Person': ['Sam', 'Peter', 'John', 'Sam', 'Joe', 'Mike'],
    'Sales': [300, 400, 350, 500, 200, 150]
}

df = pd.DataFrame(d)
df
# Out:
#   Company Person  Sales
# 0    GOOG    Sam    300
# 1    MSFT  Peter    400
# 2     AMZ   John    350
# 3    GOOG    Sam    500
# 4    MSFT    Joe    200
# 5     AMZ   Mike    150

# %%
byComp = df.groupby(['Company'])
byComp.mean('Sales')
# Out:
#          Sales
# Company
# AMZ      250.0
# GOOG     400.0
# MSFT     300.0

# %% [markdown]
# # Aggregate Function

# %%
byCompPerson = df.groupby(['Company', 'Person'])
byCompPerson.mean('Sales')
# Out:
#                 Sales
# Company Person
# AMZ     John    350.0
#         Mike    150.0
# GOOG    Sam     400.0
# MSFT    Joe     200.0
#         Peter   400.0

# %%
byComp.sum('Sales')
# Out:
#          Sales
# Company
# AMZ        500
# GOOG       800
# MSFT       600

# %%
byComp.count()[['Person', 'Sales']]
# Out:
#          Person  Sales
# Company
# AMZ           2      2
# GOOG          2      2
# MSFT          2      2

# %%
df.groupby('Company').sum('Sales').loc['MSFT']
# Out:
# Sales    600
# Name: MSFT, dtype: int64

# %%
df.groupby('Company').sum('Sales')['Sales'].loc['MSFT']
# Out:
# 600

# %%
df.groupby('Company').min()
# Out:
#         Person  Sales
# Company
# AMZ       John    150
# GOOG       Sam    300
# MSFT       Joe    200

# %%
df.groupby('Company').max()
# Out:
#         Person  Sales
# Company
# AMZ       Mike    350
# GOOG       Sam    500
# MSFT     Peter    400

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min    25%    50%    75%    max
# Company
# AMZ       2.0  250.0  141.421356  150.0  200.0  250.0  300.0  350.0
# GOOG      2.0  400.0  141.421356  300.0  350.0  400.0  450.0  500.0
# MSFT      2.0  300.0  141.421356  200.0  250.0  300.0  350.0  400.0

# %%
df.groupby('Company').describe().transpose()
# Out:
# Company             AMZ        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   250.000000  400.000000  300.000000
#       std    141.421356  141.421356  141.421356
#       min    150.000000  300.000000  200.000000
#       25%    200.000000  350.000000  250.000000
#       50%    250.000000  400.000000  300.000000
#       75%    300.000000  450.000000  350.000000
#       max    350.000000  500.000000  400.000000
