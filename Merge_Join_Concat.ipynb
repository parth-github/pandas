# %% [markdown]
# <a href="https://colab.research.google.com/github/parth-github/pandas/blob/master/Merge_Join_Concat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Merging, Joining, Concatenating

# %%
import numpy as np
import pandas as pd

# %%
d = {
    'A' : ['A0', 'A1', 'A2', 'A3'],
    'B' : ['B0', 'B1', 'B2', 'B3'],
    'C' : ['C0', 'C1', 'C2', 'C3'],
    'D' : ['D0', 'D1', 'D2', 'D3']
}
index=[0,1,2,3]
df1 = pd.DataFrame(d,index)
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
d = {
    'A' : ['A4', 'A5', 'A6', 'A7'],
    'B' : ['B4', 'B5', 'B6', 'B7'],
    'C' : ['C4', 'C5', 'C6', 'C7'],
    'D' : ['D4', 'D5', 'D6', 'D7']
}
index=[4,5,6,7]
df2 = pd.DataFrame(d,index)
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
d = {
    'A' : ['A8', 'A9', 'A10', 'A11'],
    'B' : ['B8', 'B9', 'B10', 'B11'],
    'C' : ['C8', 'C9', 'C10', 'C11'],
    'D' : ['D8', 'D9', 'D10', 'D11']
}
index=[8, 9, 10, 11]
df3 = pd.DataFrame(d,index)
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
# @title Concat
# Dimension should match along the axis of concatenation

pd.concat([df1, df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df2.index.names=['df2_index']

# %%
df2
# Out:
#             A   B   C   D
# df2_index
# 4          A4  B4  C4  D4
# 5          A5  B5  C5  D5
# 6          A6  B6  C6  D6
# 7          A7  B7  C7  D7

# %%
# @title concat between two dataframes columns having similar indexes

d = {
    'A' : ['A4', 'A5', 'A6', 'A8'],
    'B' : ['B4', 'B5', 'B6', 'B8'],
    'C' : ['C4', 'C5', 'C6', 'C8'],
    'E' : ['D4', 'D5', 'D6', 'D8']
}
index=[4,5,6,8]
df2_1 = pd.DataFrame(d,index)
df2_1
# Out:
#     A   B   C   E
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 8  A8  B8  C8  D8

# %%
pd.concat([df2, df2_1])
# Out:
#     A   B   C    D    E
# 4  A4  B4  C4   D4  NaN
# 5  A5  B5  C5   D5  NaN
# 6  A6  B6  C6   D6  NaN
# 7  A7  B7  C7   D7  NaN
# 4  A4  B4  C4  NaN   D4
# 5  A5  B5  C5  NaN   D5
# 6  A6  B6  C6  NaN   D6
# 8  A8  B8  C8  NaN   D8

# %%
#@title Outer Join
pd.concat([df2, df2_1],
          axis=1,
          join='outer', # or inner
          keys=['A', 'B'])
# Out:
#      A                   B
#      A    B    C    D    A    B    C    E
# 4   A4   B4   C4   D4   A4   B4   C4   D4
# 5   A5   B5   C5   D5   A5   B5   C5   D5
# 6   A6   B6   C6   D6   A6   B6   C6   D6
# 7   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8  NaN  NaN  NaN  NaN   A8   B8   C8   D8

# %% [markdown]
# # Merge

# %%
#@title Left Merge

pd.merge(left=df2,
         right=df2_1,
         on='A',
         #left_on='A', right_on='B',
         #left_index=True, right_index=True,
         how='left',
         suffixes=('_left', '_right'))
# Out:
#   A_left B_left C_left   D A_right B_right C_right    E
# 0     A4     B4     C4  D4     NaN     NaN     NaN  NaN
# 1     A5     B5     C5  D5     NaN     NaN     NaN  NaN
# 2     A6     B6     C6  D6     NaN     NaN     NaN  NaN
# 3     A7     B7     C7  D7     NaN     NaN     NaN  NaN

# %%
#@title Inner Merge

pd.merge(left=df2,
         right=df2_1,
         on='A',
         how='inner')
# Out:
#     A B_x C_x   D B_y C_y   E
# 0  A4  B4  C4  D4  B4  C4  D4
# 1  A5  B5  C5  D5  B5  C5  D5
# 2  A6  B6  C6  D6  B6  C6  D6

# %%
#@title Outer Merge

pd.merge(left=df2,
         right=df2_1,
         on='A',
         how='outer')
# Out:
#     A  B_x  C_x    D  B_y  C_y    E
# 0  A4   B4   C4   D4   B4   C4   D4
# 1  A5   B5   C5   D5   B5   C5   D5
# 2  A6   B6   C6   D6   B6   C6   D6
# 3  A7   B7   C7   D7  NaN  NaN  NaN
# 4  A8  NaN  NaN  NaN   B8   C8   D8

# %%
#@title Cross Merge

pd.merge(left=df2,
         right=df2_1,
         how='cross')
# Out:
#    A_x B_x C_x   D A_y B_y C_y   E
# 0   A4  B4  C4  D4  A4  B4  C4  D4
# 1   A4  B4  C4  D4  A5  B5  C5  D5
# 2   A4  B4  C4  D4  A6  B6  C6  D6
# 3   A4  B4  C4  D4  A8  B8  C8  D8
# 4   A5  B5  C5  D5  A4  B4  C4  D4
# 5   A5  B5  C5  D5  A5  B5  C5  D5
# 6   A5  B5  C5  D5  A6  B6  C6  D6
# 7   A5  B5  C5  D5  A8  B8  C8  D8
# 8   A6  B6  C6  D6  A4  B4  C4  D4
# 9   A6  B6  C6  D6  A5  B5  C5  D5
# 10  A6  B6  C6  D6  A6  B6  C6  D6
# 11  A6  B6  C6  D6  A8  B8  C8  D8
# 12  A7  B7  C7  D7  A4  B4  C4  D4
# 13  A7  B7  C7  D7  A5  B5  C5  D5
# 14  A7  B7  C7  D7  A6  B6  C6  D6
# 15  A7  B7  C7  D7  A8  B8  C8  D8

# %% [markdown]
# # Join

# %%
#@title Joining
df2.join(df2_1,
         lsuffix='_left', rsuffix='_right',
         how='inner'
         )
# Out:
#   A_left B_left C_left   D A_right B_right C_right   E
# 4     A4     B4     C4  D4      A4      B4      C4  D4
# 5     A5     B5     C5  D5      A5      B5      C5  D5
# 6     A6     B6     C6  D6      A6      B6      C6  D6
