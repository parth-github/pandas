# %% [markdown]
# <a href="https://colab.research.google.com/github/parth-github/pandas/blob/master/pandas-missing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Pandas Part - II

# %% [markdown]
# # Handling missing value: Dropna(), fillna()

# %%
import numpy as np
import pandas as pd

# %%
# Create dataframe from dictionary
d = {
    'a': [1,2,4],
    'b': [3,np.nan,4],
    'c': [5,np.nan,np.nan]
}

df = pd.DataFrame(d)
df
# Out:
#    a    b    c
# 0  1  3.0  5.0
# 1  2  NaN  NaN
# 2  4  4.0  NaN

# %%
# @title drop ROWS which are having missing value
df.dropna()
# Out:
#    a    b    c
# 0  1  3.0  5.0

# %%
# @title drop COLUMNS which are having missing value
df.dropna(axis=1)
# Out:
#    a
# 0  1
# 1  2
# 2  4

# %%
# @title drop those rows which are having NaN in both 'b' and 'c' columns
df.dropna(axis=0,
          how='all',
          subset=['b', 'c'])
# Out:
#    a    b    c
# 0  1  3.0  5.0
# 2  4  4.0  NaN

# %%
# @title drop those rows which are having NaN in any 'b' and 'c' columns
df.dropna(axis=0,
          how='any',
          subset=['b', 'c'])
# Out:
#    a    b    c
# 0  1  3.0  5.0

# %%
# @title drop those COLUMNS which are having NaN in any row
df.dropna(axis=1,
          how='any',
          ) #subset=['b', 'c']
# Out:
#    a
# 0  1
# 1  2
# 2  4

# %%
# @title drop those COLUMNS which are having NaN in all row
# add a column with all null values

df['d'] = np.NaN * 3
df

df.dropna(axis=1,
          how='all',
          )
# Out:
#    a    b    c
# 0  1  3.0  5.0
# 1  2  NaN  NaN
# 2  4  4.0  NaN

# %%
# @title Drop ROWS which are having ATLEAST 2 NaN values

df.dropna(axis=0,
          thresh=2)
# Out:
#    a    b    c   d
# 0  1  3.0  5.0 NaN
# 2  4  4.0  NaN NaN

# %%
# @title Drop COLUMNS which are having ATLEAST 2 NaN values

df.dropna(axis=1,
          thresh=2)
# Out:
#    a    b
# 0  1  3.0
# 1  2  NaN
# 2  4  4.0

# %%
df
# Out:
#    a    b    c   d
# 0  1  3.0  5.0 NaN
# 1  2  NaN  NaN NaN
# 2  4  4.0  NaN NaN

# %% [markdown]
# # Fill Missing values

# %%
# @title Fill fields with text
df.fillna(value='FILL VALUE')
# Out:
#    a           b           c           d
# 0  1         3.0         5.0  FILL VALUE
# 1  2  FILL VALUE  FILL VALUE  FILL VALUE
# 2  4         4.0  FILL VALUE  FILL VALUE

# %%
# @title Fill column b with average value
df['b']. \
  fillna(
    value=df['b'] \
      .mean())
# Out:
# 0    3.0
# 1    3.5
# 2    4.0
# Name: b, dtype: float64
